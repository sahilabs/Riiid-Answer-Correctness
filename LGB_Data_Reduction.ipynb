# %%
import seaborn as sns
import numpy as np
import pandas as pd
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
import gc
import psutil
import random
import torch
import tensorflow as tf
import tensorflow.keras.backend as K
import tensorflow.keras.layers as layers
import tensorflow.keras.models as Models
from sklearn.model_selection import GroupKFold
from torch.utils.data import DataLoader,TensorDataset
from torch import Tensor
import warnings
#warnings.simplefilter(action='ignore',category=Warning)

# %%
def seed_everything(seed): 
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
seed_everything(42)

# %%
#import data_point
data_1=np.load('../input/sampling-points-50lakh/data_point_1.npy')
data_0=np.load('../input/sampling-points-50lakh/data_point_2.npy')
data_1=np.insert(data_1,8,1,axis=1)
data_0=np.insert(data_0,8,0,axis=1)
data_0=data_0[np.nonzero(~pd.DataFrame(data_0).isna()[0].values)]
train=np.append(data_1,data_0,axis=0)
np.random.shuffle(train)
del data_1,data_0

# %%
target=train[:,-1]
train=train[:,0:-1]

# %% [markdown]
# # LGB

# %%
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
fit_params = {
    "num_boost_round": 100_000,
    "early_stopping_rounds": 50,
    "verbose_eval": 10,
                 }
bst_params =  {
                'num_leaves': 350,
                'n_estimators': 4000,
                'max_bin':700,
                'min_child_weight': 0.03454472573214212,
                'feature_fraction': 0.58,
                'bagging_fraction': 0.58,
                #'min_data_in_leaf': 106,
                'objective': 'binary',
                'max_depth': -1,
                'learning_rate': 0.09,
                "boosting_type": "gbdt",
                "bagging_seed": 11,
                "metric": 'auc',
                "verbosity": -1,
                'reg_alpha': 0.3899927210061127,
                'reg_lambda': 0.6485237330340494,
                'random_state': 47
                }
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
features=['Day_passed', 'timestamp_diff', 'Avg_prior_question_elapsed_time','Percent_of_student_Answered_Correctly','no_of_question_correct_answered', 'moving_explaination','no_of_question_answered', 'moving_average_index']

# %%
lgb_model=[]
skf=StratifiedKFold(n_splits=4, random_state=42, shuffle=True)
fold=0
for train_idx,val_idx in skf.split(train,target):
    print('FOLDS:',fold+1)
    
    train_set=lgb.Dataset( train[train_idx],label=target[train_idx])
    val_set=lgb.Dataset(train[val_idx],label=target[val_idx])
    
    model = lgb.train(bst_params,train_set=train_set,valid_sets=[train_set, val_set],
                      valid_names=["train", "valid"],**fit_params,
                      feature_name=features,)
    lgb_model.append(model)
    lgb.plot_importance(model, importance_type='gain')
    plt.show()
# Out:
# FOLDS: 1
# /opt/conda/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 50 rounds
# [10]	train's auc: 0.816486	valid's auc: 0.814499
# [20]	train's auc: 0.818852	valid's auc: 0.816595
# [30]	train's auc: 0.822799	valid's auc: 0.820225
# [40]	train's auc: 0.826373	valid's auc: 0.823463
# [50]	train's auc: 0.828882	valid's auc: 0.825615
# [60]	train's auc: 0.830667	valid's auc: 0.827065
# [70]	train's auc: 0.83274	valid's auc: 0.828787
# [80]	train's auc: 0.834185	valid's auc: 0.829848
# [90]	train's auc: 0.835593	valid's auc: 0.830915
# [100]	train's auc: 0.836733	valid's auc: 0.831764
# [110]	train's auc: 0.837837	valid's auc: 0.832524
# [120]	train's auc: 0.838861	valid's auc: 0.833177
# [130]	train's auc: 0.839806	valid's auc: 0.83373
# [140]	train's auc: 0.840678	valid's auc: 0.834208
# [150]	train's auc: 0.841454	valid's auc: 0.834604
# [160]	train's auc: 0.842211	valid's auc: 0.834988
# [170]	train's auc: 0.84289	valid's auc: 0.835249
# [180]	train's auc: 0.843537	valid's auc: 0.835494
# [190]	train's auc: 0.844115	valid's auc: 0.835683
# [200]	train's auc: 0.844738	valid's auc: 0.835923
# [210]	train's auc: 0.845283	valid's auc: 0.836064
# [220]	train's auc: 0.845898	valid's auc: 0.836298
# [230]	train's auc: 0.846398	valid's auc: 0.83641
# [240]	train's auc: 0.846928	valid's auc: 0.836601
# [250]	train's auc: 0.847431	valid's auc: 0.836706
# [260]	train's auc: 0.847943	valid's auc: 0.836804
# [270]	train's auc: 0.848419	valid's auc: 0.8369
# [280]	train's auc: 0.848979	valid's auc: 0.837075
# [290]	train's auc: 0.849403	valid's auc: 0.837127
# [300]	train's auc: 0.849892	valid's auc: 0.837249
# [310]	train's auc: 0.850458	valid's auc: 0.837496
# [320]	train's auc: 0.850856	valid's auc: 0.837577
# [330]	train's auc: 0.851401	valid's auc: 0.837748
# [340]	train's auc: 0.851847	valid's auc: 0.837812
# [350]	train's auc: 0.852236	valid's auc: 0.837851
# [360]	train's auc: 0.85264	valid's auc: 0.837896
# [370]	train's auc: 0.853023	valid's auc: 0.837947
# [380]	train's auc: 0.853459	valid's auc: 0.83804
# [390]	train's auc: 0.853852	valid's auc: 0.838093
# [400]	train's auc: 0.854207	valid's auc: 0.838128
# [410]	train's auc: 0.854585	valid's auc: 0.838157
# [420]	train's auc: 0.854986	valid's auc: 0.838205
# [430]	train's auc: 0.85545	valid's auc: 0.838283
# [440]	train's auc: 0.85593	valid's auc: 0.838456
# [450]	train's auc: 0.856324	valid's auc: 0.838499
# [460]	train's auc: 0.85667	valid's auc: 0.838517
# [470]	train's auc: 0.857055	valid's auc: 0.838548
# [480]	train's auc: 0.857438	valid's auc: 0.838579
# [490]	train's auc: 0.857849	valid's auc: 0.838623
# [500]	train's auc: 0.858228	valid's auc: 0.838667
# [510]	train's auc: 0.858598	valid's auc: 0.838693
# [520]	train's auc: 0.858926	valid's auc: 0.838754
# [530]	train's auc: 0.859321	valid's auc: 0.838811
# [540]	train's auc: 0.859659	valid's auc: 0.838868
# [550]	train's auc: 0.860033	valid's auc: 0.838881
# [560]	train's auc: 0.860339	valid's auc: 0.838912
# [570]	train's auc: 0.860706	valid's auc: 0.838932
# [580]	train's auc: 0.86108	valid's auc: 0.838991
# [590]	train's auc: 0.861423	valid's auc: 0.839032
# [600]	train's auc: 0.861703	valid's auc: 0.839031
# [610]	train's auc: 0.862025	valid's auc: 0.839038
# [620]	train's auc: 0.862381	valid's auc: 0.83905
# [630]	train's auc: 0.862761	valid's auc: 0.839079
# [640]	train's auc: 0.863083	valid's auc: 0.839107
# [650]	train's auc: 0.863383	valid's auc: 0.839165
# [660]	train's auc: 0.86372	valid's auc: 0.839216
# [670]	train's auc: 0.864064	valid's auc: 0.839253
# [680]	train's auc: 0.864357	valid's auc: 0.83926
# [690]	train's auc: 0.864723	valid's auc: 0.839296
# [700]	train's auc: 0.865154	valid's auc: 0.8394
# [710]	train's auc: 0.865511	valid's auc: 0.839422
# [720]	train's auc: 0.86584	valid's auc: 0.839475
# [730]	train's auc: 0.866241	valid's auc: 0.839543
# [740]	train's auc: 0.866537	valid's auc: 0.839558
# [750]	train's auc: 0.866859	valid's auc: 0.839565
# [760]	train's auc: 0.867151	valid's auc: 0.839567
# [770]	train's auc: 0.867464	valid's auc: 0.839561
# [780]	train's auc: 0.867839	valid's auc: 0.839604
# [790]	train's auc: 0.868224	valid's auc: 0.839653
# [800]	train's auc: 0.868574	valid's auc: 0.839675
# [810]	train's auc: 0.868902	valid's auc: 0.839712
# [820]	train's auc: 0.869266	valid's auc: 0.839785
# [830]	train's auc: 0.869556	valid's auc: 0.839806
# [840]	train's auc: 0.869848	valid's auc: 0.839822
# [850]	train's auc: 0.870143	valid's auc: 0.839821
# [860]	train's auc: 0.870439	valid's auc: 0.839818
# [870]	train's auc: 0.870752	valid's auc: 0.839827
# [880]	train's auc: 0.87104	valid's auc: 0.839853
# [890]	train's auc: 0.871347	valid's auc: 0.839854
# [900]	train's auc: 0.871624	valid's auc: 0.839857
# [910]	train's auc: 0.871911	valid's auc: 0.839865
# [920]	train's auc: 0.872212	valid's auc: 0.839871
# [930]	train's auc: 0.872544	valid's auc: 0.839878
# [940]	train's auc: 0.872827	valid's auc: 0.83988
# [950]	train's auc: 0.873099	valid's auc: 0.839889
# [960]	train's auc: 0.8734	valid's auc: 0.839908
# [970]	train's auc: 0.87375	valid's auc: 0.839929
# [980]	train's auc: 0.874062	valid's auc: 0.839916
# [990]	train's auc: 0.874359	valid's auc: 0.839933
# [1000]	train's auc: 0.874617	valid's auc: 0.83994
# [1010]	train's auc: 0.874895	valid's auc: 0.839955
# [1020]	train's auc: 0.875161	valid's auc: 0.839958
# [1030]	train's auc: 0.875417	valid's auc: 0.839951
# [1040]	train's auc: 0.875686	valid's auc: 0.839962
# [1050]	train's auc: 0.875999	valid's auc: 0.839982
# [1060]	train's auc: 0.876255	valid's auc: 0.839975
# [1070]	train's auc: 0.876535	valid's auc: 0.839974
# [1080]	train's auc: 0.8768	valid's auc: 0.839975
# [1090]	train's auc: 0.877075	valid's auc: 0.839977
# [1100]	train's auc: 0.877353	valid's auc: 0.839978
# Early stopping, best iteration is:
# [1056]	train's auc: 0.87616	valid's auc: 0.839985
# FOLDS: 1
# Training until validation scores don't improve for 50 rounds
# [10]	train's auc: 0.81618	valid's auc: 0.815075
# [20]	train's auc: 0.818608	valid's auc: 0.817053
# [30]	train's auc: 0.822596	valid's auc: 0.820752
# [40]	train's auc: 0.826171	valid's auc: 0.824006
# [50]	train's auc: 0.828681	valid's auc: 0.826188
# [60]	train's auc: 0.830449	valid's auc: 0.827669
# [70]	train's auc: 0.832524	valid's auc: 0.829387
# [80]	train's auc: 0.833963	valid's auc: 0.830462
# [90]	train's auc: 0.835437	valid's auc: 0.831601
# [100]	train's auc: 0.836635	valid's auc: 0.832483
# [110]	train's auc: 0.837747	valid's auc: 0.833263
# [120]	train's auc: 0.838817	valid's auc: 0.833952
# [130]	train's auc: 0.839753	valid's auc: 0.834508
# [140]	train's auc: 0.840624	valid's auc: 0.834978
# [150]	train's auc: 0.841372	valid's auc: 0.835348
# [160]	train's auc: 0.842118	valid's auc: 0.835728
# [170]	train's auc: 0.842823	valid's auc: 0.836042
# [180]	train's auc: 0.843472	valid's auc: 0.836279
# [190]	train's auc: 0.844034	valid's auc: 0.836454
# [200]	train's auc: 0.844651	valid's auc: 0.836719
# [210]	train's auc: 0.845184	valid's auc: 0.836844
# [220]	train's auc: 0.845782	valid's auc: 0.837044
# [230]	train's auc: 0.84626	valid's auc: 0.837172
# [240]	train's auc: 0.846811	valid's auc: 0.837332
# [250]	train's auc: 0.847334	valid's auc: 0.837474
# [260]	train's auc: 0.847847	valid's auc: 0.837605
# [270]	train's auc: 0.848322	valid's auc: 0.837722
# [280]	train's auc: 0.848745	valid's auc: 0.837791
# [290]	train's auc: 0.849178	valid's auc: 0.837857
# [300]	train's auc: 0.84971	valid's auc: 0.838022
# [310]	train's auc: 0.850132	valid's auc: 0.838122
# [320]	train's auc: 0.850586	valid's auc: 0.838183
# [330]	train's auc: 0.850991	valid's auc: 0.838239
# [340]	train's auc: 0.85147	valid's auc: 0.838366
# [350]	train's auc: 0.851968	valid's auc: 0.838497
# [360]	train's auc: 0.852419	valid's auc: 0.838577
# [370]	train's auc: 0.852867	valid's auc: 0.83866
# [380]	train's auc: 0.853253	valid's auc: 0.838711
# [390]	train's auc: 0.853682	valid's auc: 0.838807
# [400]	train's auc: 0.854094	valid's auc: 0.838883
# [410]	train's auc: 0.854446	valid's auc: 0.83891
# [420]	train's auc: 0.854844	valid's auc: 0.838999
# [430]	train's auc: 0.855312	valid's auc: 0.839143
# [440]	train's auc: 0.855797	valid's auc: 0.839311
# [450]	train's auc: 0.856151	valid's auc: 0.839323
# [460]	train's auc: 0.856554	valid's auc: 0.839375
# [470]	train's auc: 0.856951	valid's auc: 0.839407
# [480]	train's auc: 0.857356	valid's auc: 0.839442
# [490]	train's auc: 0.857728	valid's auc: 0.839453
# [500]	train's auc: 0.858108	valid's auc: 0.839492
# [510]	train's auc: 0.858496	valid's auc: 0.839513
# [520]	train's auc: 0.858908	valid's auc: 0.839537
# [530]	train's auc: 0.859259	valid's auc: 0.839551
# [540]	train's auc: 0.859592	valid's auc: 0.839589
# [550]	train's auc: 0.859949	valid's auc: 0.839612
# [560]	train's auc: 0.86029	valid's auc: 0.839628
# [570]	train's auc: 0.860623	valid's auc: 0.839644
# [580]	train's auc: 0.860963	valid's auc: 0.839655
# [590]	train's auc: 0.861334	valid's auc: 0.83968
# [600]	train's auc: 0.861653	valid's auc: 0.839689
# [610]	train's auc: 0.861971	valid's auc: 0.839691
# [620]	train's auc: 0.862347	valid's auc: 0.839701
# [630]	train's auc: 0.862665	valid's auc: 0.839706
# [640]	train's auc: 0.862889	valid's auc: 0.839718
# [650]	train's auc: 0.863193	valid's auc: 0.839734
# [660]	train's auc: 0.863544	valid's auc: 0.839769
# [670]	train's auc: 0.863926	valid's auc: 0.839791
# [680]	train's auc: 0.864274	valid's auc: 0.839803
# [690]	train's auc: 0.864613	valid's auc: 0.83982
# [700]	train's auc: 0.86493	valid's auc: 0.839828
# [710]	train's auc: 0.865283	valid's auc: 0.839853
# [720]	train's auc: 0.865589	valid's auc: 0.839865
# [730]	train's auc: 0.865971	valid's auc: 0.839919
# [740]	train's auc: 0.866333	valid's auc: 0.839955
# [750]	train's auc: 0.866654	valid's auc: 0.839965
# [760]	train's auc: 0.867015	valid's auc: 0.839989
# [770]	train's auc: 0.867373	valid's auc: 0.840029
# [780]	train's auc: 0.867687	valid's auc: 0.840028
# [790]	train's auc: 0.868023	valid's auc: 0.840046
# [800]	train's auc: 0.868301	valid's auc: 0.840046
# [810]	train's auc: 0.868641	valid's auc: 0.840071
# [820]	train's auc: 0.868976	valid's auc: 0.840091
# [830]	train's auc: 0.869272	valid's auc: 0.840099
# [840]	train's auc: 0.869572	valid's auc: 0.840106
# [850]	train's auc: 0.869898	valid's auc: 0.840114
# [860]	train's auc: 0.870202	valid's auc: 0.840109
# [870]	train's auc: 0.87055	valid's auc: 0.840133
# [880]	train's auc: 0.870848	valid's auc: 0.840142
# [890]	train's auc: 0.871182	valid's auc: 0.840159
# [900]	train's auc: 0.87147	valid's auc: 0.84017
# [910]	train's auc: 0.871767	valid's auc: 0.840179
# [920]	train's auc: 0.872077	valid's auc: 0.840186
# [930]	train's auc: 0.872383	valid's auc: 0.840186
# [940]	train's auc: 0.872683	valid's auc: 0.840196
# [950]	train's auc: 0.872942	valid's auc: 0.840196
# [960]	train's auc: 0.873205	valid's auc: 0.840189
# [970]	train's auc: 0.873514	valid's auc: 0.840214
# [980]	train's auc: 0.873836	valid's auc: 0.840202
# [990]	train's auc: 0.87417	valid's auc: 0.840213
# [1000]	train's auc: 0.874497	valid's auc: 0.840236
# [1010]	train's auc: 0.874817	valid's auc: 0.840244
# [1020]	train's auc: 0.875129	valid's auc: 0.840257
# [1030]	train's auc: 0.875423	valid's auc: 0.840272
# [1040]	train's auc: 0.875751	valid's auc: 0.840275
# [1050]	train's auc: 0.876014	valid's auc: 0.840264
# [1060]	train's auc: 0.876328	valid's auc: 0.840278
# [1070]	train's auc: 0.876633	valid's auc: 0.840284
# [1080]	train's auc: 0.876983	valid's auc: 0.840364
# [1090]	train's auc: 0.877275	valid's auc: 0.840386
# [1100]	train's auc: 0.877525	valid's auc: 0.840378
# [1110]	train's auc: 0.877806	valid's auc: 0.840387
# [1120]	train's auc: 0.878099	valid's auc: 0.840406
# [1130]	train's auc: 0.878379	valid's auc: 0.840414
# [1140]	train's auc: 0.878662	valid's auc: 0.84042
# [1150]	train's auc: 0.87896	valid's auc: 0.840441
# [1160]	train's auc: 0.879244	valid's auc: 0.840447
# [1170]	train's auc: 0.879543	valid's auc: 0.840439
# [1180]	train's auc: 0.879813	valid's auc: 0.840439
# [1190]	train's auc: 0.880126	valid's auc: 0.840461
# [1200]	train's auc: 0.880399	valid's auc: 0.84048
# [1210]	train's auc: 0.880639	valid's auc: 0.840473
# [1220]	train's auc: 0.880916	valid's auc: 0.840473
# [1230]	train's auc: 0.88122	valid's auc: 0.840496
# [1240]	train's auc: 0.88149	valid's auc: 0.840488
# [1250]	train's auc: 0.881729	valid's auc: 0.840477
# [1260]	train's auc: 0.882036	valid's auc: 0.840518
# [1270]	train's auc: 0.882308	valid's auc: 0.840522
# [1280]	train's auc: 0.882532	valid's auc: 0.840521
# [1290]	train's auc: 0.882808	valid's auc: 0.840516
# [1300]	train's auc: 0.883071	valid's auc: 0.840514
# [1310]	train's auc: 0.883333	valid's auc: 0.840511
# Early stopping, best iteration is:
# [1266]	train's auc: 0.882217	valid's auc: 0.840523
# FOLDS: 1
# Training until validation scores don't improve for 50 rounds
# [10]	train's auc: 0.816303	valid's auc: 0.81432
# [20]	train's auc: 0.818753	valid's auc: 0.816342
# [30]	train's auc: 0.822789	valid's auc: 0.820157
# [40]	train's auc: 0.826322	valid's auc: 0.82344
# [50]	train's auc: 0.828822	valid's auc: 0.82562
# [60]	train's auc: 0.830593	valid's auc: 0.827111
# [70]	train's auc: 0.832666	valid's auc: 0.828846
# [80]	train's auc: 0.834129	valid's auc: 0.829915
# [90]	train's auc: 0.835598	valid's auc: 0.831028
# [100]	train's auc: 0.836806	valid's auc: 0.831944
# [110]	train's auc: 0.837923	valid's auc: 0.832729
# [120]	train's auc: 0.838997	valid's auc: 0.833409
# [130]	train's auc: 0.839934	valid's auc: 0.833958
# [140]	train's auc: 0.840829	valid's auc: 0.834446
# [150]	train's auc: 0.841585	valid's auc: 0.834827
# [160]	train's auc: 0.842385	valid's auc: 0.835271
# [170]	train's auc: 0.843062	valid's auc: 0.835532
# [180]	train's auc: 0.84371	valid's auc: 0.835775
# [190]	train's auc: 0.844294	valid's auc: 0.835955
# [200]	train's auc: 0.844925	valid's auc: 0.836208
# [210]	train's auc: 0.845528	valid's auc: 0.836404
# [220]	train's auc: 0.84609	valid's auc: 0.83659
# [230]	train's auc: 0.846587	valid's auc: 0.836718
# [240]	train's auc: 0.847081	valid's auc: 0.836819
# [250]	train's auc: 0.847637	valid's auc: 0.836979
# [260]	train's auc: 0.848229	valid's auc: 0.837196
# [270]	train's auc: 0.84868	valid's auc: 0.837297
# [280]	train's auc: 0.849155	valid's auc: 0.837416
# [290]	train's auc: 0.849604	valid's auc: 0.837502
# [300]	train's auc: 0.85006	valid's auc: 0.837581
# [310]	train's auc: 0.850548	valid's auc: 0.837704
# [320]	train's auc: 0.850986	valid's auc: 0.837769
# [330]	train's auc: 0.851453	valid's auc: 0.837851
# [340]	train's auc: 0.851857	valid's auc: 0.837885
# [350]	train's auc: 0.852281	valid's auc: 0.83794
# [360]	train's auc: 0.852764	valid's auc: 0.838046
# [370]	train's auc: 0.853178	valid's auc: 0.838091
# [380]	train's auc: 0.853572	valid's auc: 0.838134
# [390]	train's auc: 0.853961	valid's auc: 0.838177
# [400]	train's auc: 0.854367	valid's auc: 0.838229
# [410]	train's auc: 0.854785	valid's auc: 0.838265
# [420]	train's auc: 0.85516	valid's auc: 0.838297
# [430]	train's auc: 0.85553	valid's auc: 0.838343
# [440]	train's auc: 0.855939	valid's auc: 0.838426
# [450]	train's auc: 0.856316	valid's auc: 0.83848
# [460]	train's auc: 0.856701	valid's auc: 0.838524
# [470]	train's auc: 0.857085	valid's auc: 0.838562
# [480]	train's auc: 0.857436	valid's auc: 0.838581
# [490]	train's auc: 0.85784	valid's auc: 0.838611
# [500]	train's auc: 0.858184	valid's auc: 0.838651
# [510]	train's auc: 0.858566	valid's auc: 0.838683
# [520]	train's auc: 0.858959	valid's auc: 0.838737
# [530]	train's auc: 0.859321	valid's auc: 0.838765
# [540]	train's auc: 0.859662	valid's auc: 0.838802
# [550]	train's auc: 0.860019	valid's auc: 0.838813
# [560]	train's auc: 0.860359	valid's auc: 0.838823
# [570]	train's auc: 0.860688	valid's auc: 0.838831
# [580]	train's auc: 0.861026	valid's auc: 0.838832
# [590]	train's auc: 0.861346	valid's auc: 0.838853
# [600]	train's auc: 0.861699	valid's auc: 0.838883
# [610]	train's auc: 0.862015	valid's auc: 0.838884
# [620]	train's auc: 0.862349	valid's auc: 0.838895
# [630]	train's auc: 0.862745	valid's auc: 0.838928
# [640]	train's auc: 0.863069	valid's auc: 0.838931
# [650]	train's auc: 0.863436	valid's auc: 0.838965
# [660]	train's auc: 0.863766	valid's auc: 0.838987
# [670]	train's auc: 0.864086	valid's auc: 0.838997
# [680]	train's auc: 0.864386	valid's auc: 0.83901
# [690]	train's auc: 0.86469	valid's auc: 0.839018
# [700]	train's auc: 0.865017	valid's auc: 0.839035
# [710]	train's auc: 0.865361	valid's auc: 0.839077
# [720]	train's auc: 0.865686	valid's auc: 0.839087
# [730]	train's auc: 0.866022	valid's auc: 0.839091
# [740]	train's auc: 0.866349	valid's auc: 0.839097
# [750]	train's auc: 0.866655	valid's auc: 0.839095
# [760]	train's auc: 0.866948	valid's auc: 0.839104
# [770]	train's auc: 0.867318	valid's auc: 0.839157
# [780]	train's auc: 0.867647	valid's auc: 0.839175
# [790]	train's auc: 0.867956	valid's auc: 0.839193
# [800]	train's auc: 0.868256	valid's auc: 0.839195
# [810]	train's auc: 0.868614	valid's auc: 0.839284
# [820]	train's auc: 0.868899	valid's auc: 0.839311
# [830]	train's auc: 0.869266	valid's auc: 0.839371
# [840]	train's auc: 0.869591	valid's auc: 0.839389
# [850]	train's auc: 0.869903	valid's auc: 0.83939
# [860]	train's auc: 0.870211	valid's auc: 0.839398
# [870]	train's auc: 0.870551	valid's auc: 0.839426
# [880]	train's auc: 0.870882	valid's auc: 0.839438
# [890]	train's auc: 0.871189	valid's auc: 0.839438
# [900]	train's auc: 0.8715	valid's auc: 0.839448
# [910]	train's auc: 0.871794	valid's auc: 0.839446
# [920]	train's auc: 0.872117	valid's auc: 0.839446
# [930]	train's auc: 0.872422	valid's auc: 0.839448
# [940]	train's auc: 0.872707	valid's auc: 0.83945
# [950]	train's auc: 0.873015	valid's auc: 0.839446
# [960]	train's auc: 0.873371	valid's auc: 0.839472
# [970]	train's auc: 0.873669	valid's auc: 0.839474
# [980]	train's auc: 0.873941	valid's auc: 0.839471
# [990]	train's auc: 0.874232	valid's auc: 0.839459
# [1000]	train's auc: 0.87451	valid's auc: 0.83946
# [1010]	train's auc: 0.874808	valid's auc: 0.839465
# [1020]	train's auc: 0.875106	valid's auc: 0.839484
# [1030]	train's auc: 0.875397	valid's auc: 0.839483
# [1040]	train's auc: 0.875687	valid's auc: 0.839479
# [1050]	train's auc: 0.876008	valid's auc: 0.839509
# [1060]	train's auc: 0.87632	valid's auc: 0.839511
# [1070]	train's auc: 0.876573	valid's auc: 0.839506
# [1080]	train's auc: 0.87686	valid's auc: 0.83951
# [1090]	train's auc: 0.877121	valid's auc: 0.839504
# Early stopping, best iteration is:
# [1043]	train's auc: 0.875803	valid's auc: 0.839513
# FOLDS: 1
# Training until validation scores don't improve for 50 rounds
# [10]	train's auc: 0.816311	valid's auc: 0.81504
# [20]	train's auc: 0.818683	valid's auc: 0.81694
# [30]	train's auc: 0.822624	valid's auc: 0.820645
# [40]	train's auc: 0.826198	valid's auc: 0.823901
# [50]	train's auc: 0.828692	valid's auc: 0.826037
# [60]	train's auc: 0.83047	valid's auc: 0.827532
# [70]	train's auc: 0.832572	valid's auc: 0.829297
# [80]	train's auc: 0.834059	valid's auc: 0.830396
# [90]	train's auc: 0.835438	valid's auc: 0.831437
# [100]	train's auc: 0.836689	valid's auc: 0.832396
# [110]	train's auc: 0.837825	valid's auc: 0.833156
# [120]	train's auc: 0.838884	valid's auc: 0.8338
# [130]	train's auc: 0.839807	valid's auc: 0.834329
# [140]	train's auc: 0.840684	valid's auc: 0.834786
# [150]	train's auc: 0.841421	valid's auc: 0.835142
# [160]	train's auc: 0.842215	valid's auc: 0.835549
# [170]	train's auc: 0.842946	valid's auc: 0.835865
# [180]	train's auc: 0.843636	valid's auc: 0.836182
# [190]	train's auc: 0.844238	valid's auc: 0.836392
# [200]	train's auc: 0.844881	valid's auc: 0.836654
# [210]	train's auc: 0.845442	valid's auc: 0.836813
# [220]	train's auc: 0.846016	valid's auc: 0.83699
# [230]	train's auc: 0.846553	valid's auc: 0.837133
# [240]	train's auc: 0.847001	valid's auc: 0.837213
# [250]	train's auc: 0.847533	valid's auc: 0.837336
# [260]	train's auc: 0.848049	valid's auc: 0.837482
# [270]	train's auc: 0.848545	valid's auc: 0.837645
# [280]	train's auc: 0.84903	valid's auc: 0.837767
# [290]	train's auc: 0.849482	valid's auc: 0.837863
# [300]	train's auc: 0.849937	valid's auc: 0.837935
# [310]	train's auc: 0.850393	valid's auc: 0.838016
# [320]	train's auc: 0.850868	valid's auc: 0.838112
# [330]	train's auc: 0.85132	valid's auc: 0.838201
# [340]	train's auc: 0.851737	valid's auc: 0.83826
# [350]	train's auc: 0.852186	valid's auc: 0.838328
# [360]	train's auc: 0.852642	valid's auc: 0.838441
# [370]	train's auc: 0.853137	valid's auc: 0.838585
# [380]	train's auc: 0.853531	valid's auc: 0.838644
# [390]	train's auc: 0.853963	valid's auc: 0.838755
# [400]	train's auc: 0.854375	valid's auc: 0.838808
# [410]	train's auc: 0.854773	valid's auc: 0.838862
# [420]	train's auc: 0.855138	valid's auc: 0.838926
# [430]	train's auc: 0.855577	valid's auc: 0.83903
# [440]	train's auc: 0.855932	valid's auc: 0.839067
# [450]	train's auc: 0.856309	valid's auc: 0.839092
# [460]	train's auc: 0.85666	valid's auc: 0.839146
# [470]	train's auc: 0.857053	valid's auc: 0.839196
# [480]	train's auc: 0.857454	valid's auc: 0.839272
# [490]	train's auc: 0.857847	valid's auc: 0.839319
# [500]	train's auc: 0.858219	valid's auc: 0.83934
# [510]	train's auc: 0.858573	valid's auc: 0.839352
# [520]	train's auc: 0.858952	valid's auc: 0.839395
# [530]	train's auc: 0.859302	valid's auc: 0.839437
# [540]	train's auc: 0.859708	valid's auc: 0.839486
# [550]	train's auc: 0.860026	valid's auc: 0.839486
# [560]	train's auc: 0.860342	valid's auc: 0.839491
# [570]	train's auc: 0.860678	valid's auc: 0.839504
# [580]	train's auc: 0.861068	valid's auc: 0.83955
# [590]	train's auc: 0.861467	valid's auc: 0.839575
# [600]	train's auc: 0.861828	valid's auc: 0.839618
# [610]	train's auc: 0.862162	valid's auc: 0.839634
# [620]	train's auc: 0.862488	valid's auc: 0.83965
# [630]	train's auc: 0.862869	valid's auc: 0.8397
# [640]	train's auc: 0.863174	valid's auc: 0.839708
# [650]	train's auc: 0.863484	valid's auc: 0.839713
# [660]	train's auc: 0.863806	valid's auc: 0.839721
# [670]	train's auc: 0.864159	valid's auc: 0.83975
# [680]	train's auc: 0.864527	valid's auc: 0.839768
# [690]	train's auc: 0.864837	valid's auc: 0.839788
# [700]	train's auc: 0.865147	valid's auc: 0.839799
# [710]	train's auc: 0.865538	valid's auc: 0.839831
# [720]	train's auc: 0.86588	valid's auc: 0.839847
# [730]	train's auc: 0.866198	valid's auc: 0.839863
# [740]	train's auc: 0.866519	valid's auc: 0.83988
# [750]	train's auc: 0.866861	valid's auc: 0.839905
# [760]	train's auc: 0.867144	valid's auc: 0.839913
# [770]	train's auc: 0.867442	valid's auc: 0.839921
# [780]	train's auc: 0.867725	valid's auc: 0.839923
# [790]	train's auc: 0.868014	valid's auc: 0.839914
# [800]	train's auc: 0.868287	valid's auc: 0.839915
# [810]	train's auc: 0.868605	valid's auc: 0.839931
# [820]	train's auc: 0.868886	valid's auc: 0.839936
# [830]	train's auc: 0.869238	valid's auc: 0.839931
# [840]	train's auc: 0.869539	valid's auc: 0.839949
# [850]	train's auc: 0.869867	valid's auc: 0.839948
# [860]	train's auc: 0.870178	valid's auc: 0.839951
# [870]	train's auc: 0.870447	valid's auc: 0.839948
# [880]	train's auc: 0.87075	valid's auc: 0.839969
# [890]	train's auc: 0.871069	valid's auc: 0.839953
# [900]	train's auc: 0.871329	valid's auc: 0.839945
# [910]	train's auc: 0.871642	valid's auc: 0.839951
# [920]	train's auc: 0.871902	valid's auc: 0.839955
# [930]	train's auc: 0.872236	valid's auc: 0.839961
# Early stopping, best iteration is:
# [880]	train's auc: 0.87075	valid's auc: 0.839969

# %%
np.save('lgb_model.npy',lgb_model)

# %%
# %%time
# def reduce_mem_usage(df, verbose=True):
#     numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
#     start_mem = df.memory_usage().sum() / 1024**2    
#     for col in df.columns: #columns
#         col_type = df[col].dtypes
#         if col_type in numerics: #numerics
#             c_min = df[col].min()
#             c_max = df[col].max()
#             if str(col_type)[:3] == 'int':
#                 if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
#                     df[col] = df[col].astype(np.int8)
#                 elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
#                     df[col] = df[col].astype(np.int16)
#                 elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
#                     df[col] = df[col].astype(np.int32)
#                 elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
#                     df[col] = df[col].astype(np.int64)  
#             else:
#                 if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
#                     df[col] = df[col].astype(np.float16)
#                 elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
#                     df[col] = df[col].astype(np.float32)
#                 else:
#                     df[col] = df[col].astype(np.float64)    
#     end_mem = df.memory_usage().sum() / 1024**2
#     if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
#     return df

# train=pd.read_csv('../input/final-preprocessing/train.csv')
# train=reduce_mem_usage(train, verbose=True)
# ############################################################
# moving_sum_prior_question_had_explaination=np.load('../input/final-preprocessing/moving_sum_prior_question_had_explaination.npy',allow_pickle=False)
# moving_average_index=np.load('../input/final-preprocessing/moving_Avg_prior_index.npy',allow_pickle=False)
# no_of_question_answered=np.load('../input/final-preprocessing/no_of_question_answered.npy',allow_pickle=False)
# no_of_question_correct_answered=np.load('../input/final-preprocessing/no_of_question_correct_answered.npy',allow_pickle=False)
# Percent_of_student_Answered_Correctly=np.load('../input/final-preprocessing/Percent_of_student_Answered_Correctly.npy',allow_pickle=False)
# Avg_prior_question_elapsed_time=np.load('../input/final-preprocessing/Avg_prior_question_elapsed_time.npy',allow_pickle=False)
# Day_passed=np.load('../input/final-preprocessing/Day_passed.npy',allow_pickle=False)
# timestamp_diff=np.load('../input/final-preprocessing/timestamp_diff.npy',allow_pickle=False)
# prior_question_elapsed_time=np.load('../input/final-preprocessing/prior_question_elapsed_time.npy',allow_pickle=False)
# ##################################################################
# temp=moving_average_index[train['answered_correctly'].values!=-1]
# moving_sum_prior_question_had_explaination=moving_sum_prior_question_had_explaination[temp!=-2]
# del temp
# ####################################################
# train_index=np.nonzero(moving_average_index>=0)[0]
# prior_question_elapsed_time=prior_question_elapsed_time[train_index]
# gc.collect()
# def mean_normalization(array):
#     global train_index
#     array=array[train_index]
#     mean=np.mean(array)
#     std= np.std(array)
#     array=(array-mean)/std
#     return array,mean,std

# def median_normalization(array):
#     global train_index
#     array=array[train_index].copy()
#     array=array[prior_question_elapsed_time!=prior_question_elapsed_time.max()]
#     median=np.median(array)
#     std=np.std(array)
#     array=(array-median)/(std)
#     return array,median,std
# def min_max(array):
#     global train_index
#     array=array[train_index].copy()
#     array=array[prior_question_elapsed_time!=prior_question_elapsed_time.max()]
#     Min=np.min(array)
#     Max=np.max(array)
#     array=(array-Min)/(Max-Min)
#     return array,Min,Max
# ###################################################
# train=train.loc[train_index].reset_index(drop=True)
# train=train.loc[prior_question_elapsed_time!=prior_question_elapsed_time.max()]
# #########################
# mean_std=[]
# Day_passed,mean,std=median_normalization(Day_passed)# Day passed is a counter features so median normlization is good. Median normalization is sugessted when there is equally space between them
# train['Day_passed']=Day_passed
# mean_std.append([train.columns[-1],mean,std])
# del Day_passed
# gc.collect()
# #########
# timestamp_diff,mean,std=median_normalization(timestamp_diff)# median normalization is robust to outlier
# train['timestamp_diff']=timestamp_diff
# mean_std.append([train.columns[-1],mean,std])
# del timestamp_diff
# gc.collect()
# ##########
# Avg_prior_question_elapsed_time,mean,std=mean_normalization(Avg_prior_question_elapsed_time)
# Avg_prior_question_elapsed_time=Avg_prior_question_elapsed_time[prior_question_elapsed_time!=prior_question_elapsed_time.max()]
# train['Avg_prior_question_elapsed_time']=Avg_prior_question_elapsed_time
# mean_std.append([train.columns[-1],mean,std])
# del Avg_prior_question_elapsed_time
# gc.collect()
# ##########
# Percent_of_student_Answered_Correctly=Percent_of_student_Answered_Correctly[train_index]
# Percent_of_student_Answered_Correctly=Percent_of_student_Answered_Correctly[prior_question_elapsed_time!=prior_question_elapsed_time.max()]
# train['Percent_of_student_Answered_Correctly']=Percent_of_student_Answered_Correctly/100
# mean_std.append([train.columns[-1],0,100])
# del Percent_of_student_Answered_Correctly
# gc.collect()
# #######
# no_of_question_correct_answered=no_of_question_correct_answered[train_index]/no_of_question_answered[train_index]
# no_of_question_correct_answered=no_of_question_correct_answered[prior_question_elapsed_time!=prior_question_elapsed_time.max()]
# train['no_of_question_correct_answered']=no_of_question_correct_answered
# mean_std.append([train.columns[-1],0,1])
# del no_of_question_correct_answered
# gc.collect()
# #####################
# moving_sum_prior_question_had_explaination=moving_sum_prior_question_had_explaination/no_of_question_answered[train_index]
# moving_sum_prior_question_had_explaination=moving_sum_prior_question_had_explaination[prior_question_elapsed_time!=prior_question_elapsed_time.max()]
# train['moving_explaination']=moving_sum_prior_question_had_explaination
# mean_std.append(['moving_explaination',0,1])
# del moving_sum_prior_question_had_explaination
# #####################
# no_of_question_answered,mean,std=median_normalization(no_of_question_answered)#counter vairable 
# train['no_of_question_answered']=no_of_question_answered
# mean_std.append([train.columns[-1],mean,std])
# del no_of_question_answered
# gc.collect()
# ####################
# moving_average_index,mean,std=min_max(moving_average_index)
# train['moving_average_index']=moving_average_index
# mean_std.append([train.columns[-1],mean,std])
# del moving_average_index
# ###################
# np.save('scaler.npy',mean_std)
# print(mean_std)
# del mean_std
# gc.collect()
# ################################
# print(train.memory_usage().sum() / 1024**2 )
# train=reduce_mem_usage(train, verbose=True)
# print(train.memory_usage().sum() / 1024**2 )
# del prior_question_elapsed_time
# #####################################
# target_=train['answered_correctly'].values
# train.drop(columns=['answered_correctly'],inplace=True)
# #user_id=train.user_id.values #3.1 GB Ram
# train.drop(columns=['user_id'],inplace=True)

# %% [markdown]
# # Neural Network

# %%
# def plot_history(history):
#     array=list(history.history.keys())
#     score = history.history[array[1]]
#     val_score = history.history[array[3]]

#     loss = history.history['loss']
#     val_loss = history.history['val_loss']

#     epochs_range = range(EPOCHS)

#     # create subplots
#     plt.figure(figsize = (20,5))
#     plt.subplot(1, 2, 1)
#     plt.plot(epochs_range, score, label = 'Training Score')
#     plt.plot(epochs_range, val_score, label = 'Validation Score')
#     plt.legend(loc = 'lower right')
#     plt.title('Training and Validation Score')

#     plt.subplot(1, 2, 2)
#     plt.plot(epochs_range, loss, label = 'Training Loss')
#     plt.plot(epochs_range, val_loss, label = 'Validation Loss')
#     # limit y-values for beter zoom-scale
#     #plt.ylim(0.3 * np.mean(val_loss), 1.8 * np.mean(val_loss))

#     plt.legend(loc = 'upper right')
#     plt.title('Training and Validation Loss')
#     plt.show()

# %%
# class CustomCallback(tf.keras.callbacks.Callback):
#     def on_train_begin(self, logs=None):
#         self.val_score=[]
        
#     def on_epoch_end(self, epoch, logs=None):
#         #print(self.val_score)
#         self.val_score.append(logs['val_loss'])
#         if epoch % 10 == 0 or epoch == (EPOCHS -1 ):
#             print(f"The average val-loss for epoch {epoch} is {logs['val_loss']:.2f}"
#                   f" and the val-score is {logs['val_loss']}")

#     def on_train_end(self, logs=None):
#         best_epoch = np.argmin(self.val_score)
#         # get score in best epoch
#         best_score = self.val_score[best_epoch]
#         print(f"Stop training, best model was found and saved in epoch {best_epoch + 1} with val-score: {best_score}."
#               f" Final results in this fold (last epoch):") 

# def get_checkpoint_saver_callback(fold):
#     checkpt_saver = tf.keras.callbacks.ModelCheckpoint(
#         'fold-%i.h5'%fold,
#         monitor = 'val_loss',
#         verbose = 0,
#         save_best_only = True,
#         save_weights_only = True,
#         mode = 'min',
#         save_freq = 'epoch')
    
#     return checkpt_saver

# %%
# EPOCHS = 100
# BATCH_SIZE=2048#16384
# Drop_1=0.395458
# Drop_2=0.200271
# Drop_3= 0.2#463196
# FOLDS=7
# Factor=0.8
# lr=0.1#20555
# patience=8

# %%
# import tensorflow_addons as tfa
# def model(Drop_1,Drop_2,Drop_3,lr=0.01,optimizer='Adam'):
#     Input=layers.Input((8,))
#     x=layers.BatchNormalization()(Input)
#     x=tfa.layers.WeightNormalization(layers.Dense(128,activation='relu'))(x)
#     x=layers.BatchNormalization()(x)
#     x=layers.Dropout(0.2)(x)
#     x=tfa.layers.WeightNormalization(layers.Dense(64,activation='relu'))(x)
#     x=layers.BatchNormalization()(x)
#     x=layers.Dropout(0.1)(x)
#     x=tfa.layers.WeightNormalization(layers.Dense(32,activation='relu'))(x)
#     x=layers.BatchNormalization()(x)
#     x=layers.Dropout(0.1)(x)
#     x=tfa.layers.WeightNormalization(layers.Dense(16,activation='relu'))(x)
#     x=layers.BatchNormalization()(x)
#     #x=layers.Dropout(0.1)(x)
#     x=tfa.layers.WeightNormalization(layers.Dense(1,activation='sigmoid'))(x)
#     model_neural=Models.Model(Input,x)
    
#     ###################
#     bce = tf.keras.losses.BinaryCrossentropy()
#     optimizer=tf.keras.optimizers.Adam(lr=lr) if optimizer=='Adam' else tf.keras.optimizers.SGD()
#     model_neural.compile(loss=bce,optimizer=optimizer,metrics=[tf.keras.metrics.AUC()])
#     return model_neural

# %%
# def train_model():
#     FOLDS=3
#     final_score=[]
#     #print(BATCH_SIZE)
#     for i in range(1):
#         #group wise K-Fold 'user_id'
#         callbacks=[]
#         LOGGING=True
#         gkf=GroupKFold(n_splits=FOLDS)
#         groups=user_id
#         fold=0
#         OOF_val_score=[]
#         for train_idx,val_idx in gkf.split(train,target):
#             gc.collect()
#             gc.collect()
#             gc.collect()
#             fold+=1
#             print(f"FOLD{fold}")
#             #callbacks_lr = [get_lr_callback(BATCH_SIZE)]
#             reduce_lr_loss=tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',factor=Factor,patience=patience,verbose = 1,epsilon = 1e-4,mode = 'min',min_lr = 0.00001)
#             #reduce_lr_loss if the model reached to some plateau or loss is not decreasing then LR is reduced so that it won't overshoot#0.23889#50
#             callbacks=[reduce_lr_loss]
#             if(LOGGING==True):
#                 callbacks +=  [get_checkpoint_saver_callback(fold),                   
#                              CustomCallback()]
                
#             with tf.device("/gpu:0"):
#                 model_neural = model(Drop_1,Drop_2,Drop_3,lr,'Adam')
#                 history = model_neural.fit(train[train_idx], target[train_idx], 
#                           batch_size = BATCH_SIZE,
#                           epochs = EPOCHS,
#                           validation_data = (train[val_idx], target),
#                           callbacks = callbacks,verbose = 0,class_weight={0:0.55,1:0.45})


#             model_neural.load_weights('fold-%i.h5'%fold)
#             print("Train:", model_neural.evaluate(train[train_idx], target[train_idx], verbose = 0, batch_size = BATCH_SIZE, return_dict = True))
#             print("Val:", model_neural.evaluate(train[val_idx], target[val_idx], verbose = 0, batch_size = BATCH_SIZE, return_dict = True))
        
#             gc.collect()
#             gc.collect()
#             gc.collect()
#             score=model_neural.evaluate(train[val_idx], target[val_idx], verbose = 0, batch_size = BATCH_SIZE, return_dict = True)
#             OOF_val_score.append(score[list(score.keys())[-1]])
#             plot_history(history)
#             #test_preds += model_neural.predict(X_test, batch_size = BATCH_SIZE, verbose = 0)/FOLDS
#         print(np.mean(OOF_val_score))

# %%
# %%time
# history=train_model()

# %%
# target
